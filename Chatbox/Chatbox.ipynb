# %% [markdown]
# Chatbot is a computer program that simulates human conversation through voice commands or text chats or both.

# %%
#libraries needed for NLP
import nltk
nltk.download('punkt')
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
#libraries needed for Tensorflow proccessing
import tensorflow as tf, numpy as np, pandas as pd,random,json
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Load the intents.json file from from local
# from google.colab import files
# files.upload()

# another method access drive
# got to files and give access to drive
with open('/content/drive/MyDrive/Hands on Python/intents.json') as json_data:
  intents = json.load(json_data)

# %%
words = []
classes = []
documents = []
ignore = ['?']# if u want to ignore any special character
# loop through each sentence in intent's pattern
for intent in intents['intents']:
  for pattern in intent['patterns']:
    # tokenize each and every word in sentence
    w = nltk.word_tokenize(pattern)
    # add word to the words list
    words.extend(w)
    documents.append((w,intent['tag']))
    # add tag to classes list
    if intent['tag'] not in classes:
      classes.append(intent['tag'])

# %%
#Perform stemming and lower each word as well as remove duplicates
words = [stemmer.stem(w.lower()) for w in words if w not in ignore]
words = sorted(list(set(words)))

# remove duplicates classes
classes = sorted(list(set(classes)))

print(len(documents)," documents")
print(len(classes), " classes ", classes)
print(len(words), " unique stemmed words", words)
# Out:
# 28  documents
# 8  classes  ['about', 'chatbot', 'connect', 'goodbye', 'greeting', 'location', 'movies', 'thanks']
# 52  unique stemmed words ["'s", 'about', 'account', 'address', 'ani', 'anyon', 'are', 'built', 'bye', 'can', 'chatbot', 'connect', 'day', 'favourit', 'give', 'good', 'goodby', 'hello', 'help', 'hi', 'how', 'i', 'is', 'later', 'link', 'locat', 'me', 'media', 'movi', 'name', 'out', 'reach', 'recommend', 'see', 'social', 'some', 'suggest', 'tell', 'thank', 'that', 'there', 'thi', 'to', 'way', 'we', 'what', 'where', 'which', 'who', 'you', 'your', 'yourself']

# %%
# create training data
training = []
output = []
# create an empty array for output
output_empty = [0]*len(classes)

# create traning set, bag of words
for doc in documents:
  #intializing bag of words
  bag = []
  # list of tokenized words for the pattern
  pattern_words = doc[0]
  # stemming each word
  pattern_words = [stemmer.stem(word.lower()) for word in pattern_words]
  # create bag of words array
  for w in words:
    bag.append(1) if w in pattern_words else bag.append(0)
  #output is '1' for current tag and '0' for rest of other tags
  output_row = list(output_empty)
  output_row[classes.index(doc[1])] = 1

  training.append([bag, output_row])

# Shuffking features and turning it to np.array
random.shuffle(training)
training = np.array(training)

# create training lists
train_x = list(training[:,0])
train_y = list(training[:,1])
# Out:
# <ipython-input-24-137fbbcd2a86>:26: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(10,input_shape=(len(train_x[0]),)))
model.add(tf.keras.layers.Dense(10))
model.add(tf.keras.layers.Dense(len(train_y[0]),activation='softmax'))# multiclass classification - use softmax
model.compile(tf.keras.optimizers.Adam(),loss = 'categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(np.array(train_x),np.array(train_y), epochs =100, batch_size = 8, verbose=1)
model.save('model.pkl')
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 5ms/step - loss: 2.1922 - accuracy: 0.1786
# Epoch 2/100
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1633 - accuracy: 0.1786
# Epoch 3/100
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1384 - accuracy: 0.1786
# Epoch 4/100
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1168 - accuracy: 0.1786
# Epoch 5/100
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0931 - accuracy: 0.1786
# Epoch 6/100
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0722 - accuracy: 0.1786
# Epoch 7/100
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0501 - accuracy: 0.1786
# Epoch 8/100
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0291 - accuracy: 0.1786
# Epoch 9/100
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0070 - accuracy: 0.1786
# Epoch 10/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9868 - accuracy: 0.1786
# Epoch 11/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9669 - accuracy: 0.2143
# Epoch 12/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9457 - accuracy: 0.2143
# Epoch 13/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9269 - accuracy: 0.2143
# Epoch 14/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9058 - accuracy: 0.2143
# Epoch 15/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.8862 - accuracy: 0.2500
# Epoch 16/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.8656 - accuracy: 0.2500
# Epoch 17/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.8457 - accuracy: 0.2500
# Epoch 18/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.8259 - accuracy: 0.2500
# Epoch 19/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.8056 - accuracy: 0.2857
# Epoch 20/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.7869 - accuracy: 0.2857
# Epoch 21/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.7659 - accuracy: 0.2857
# Epoch 22/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.7460 - accuracy: 0.2857
# Epoch 23/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.7267 - accuracy: 0.2857
# Epoch 24/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.7066 - accuracy: 0.3214
# Epoch 25/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.6872 - accuracy: 0.3571
# Epoch 26/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.6646 - accuracy: 0.3571
# Epoch 27/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.6443 - accuracy: 0.3571
# Epoch 28/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.6240 - accuracy: 0.3929
# Epoch 29/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.6050 - accuracy: 0.4643
# Epoch 30/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.5830 - accuracy: 0.5357
# Epoch 31/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.5632 - accuracy: 0.5357
# Epoch 32/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.5414 - accuracy: 0.6429
# Epoch 33/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.5220 - accuracy: 0.6429
# Epoch 34/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.5008 - accuracy: 0.6429
# Epoch 35/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.4807 - accuracy: 0.6429
# Epoch 36/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.4589 - accuracy: 0.6786
# Epoch 37/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.4385 - accuracy: 0.6786
# Epoch 38/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.4169 - accuracy: 0.6786
# Epoch 39/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3975 - accuracy: 0.6786
# Epoch 40/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3755 - accuracy: 0.7143
# Epoch 41/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3539 - accuracy: 0.7143
# Epoch 42/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3337 - accuracy: 0.7143
# Epoch 43/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3121 - accuracy: 0.7143
# Epoch 44/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.2917 - accuracy: 0.7143
# Epoch 45/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.2720 - accuracy: 0.7143
# Epoch 46/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.2516 - accuracy: 0.7143
# Epoch 47/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.2311 - accuracy: 0.7500
# Epoch 48/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.2114 - accuracy: 0.7500
# Epoch 49/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.1922 - accuracy: 0.7500
# Epoch 50/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.1733 - accuracy: 0.7500
# Epoch 51/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.1544 - accuracy: 0.8214
# Epoch 52/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.1351 - accuracy: 0.8214
# Epoch 53/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.1174 - accuracy: 0.8214
# Epoch 54/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0980 - accuracy: 0.8214
# Epoch 55/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0806 - accuracy: 0.8214
# Epoch 56/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0619 - accuracy: 0.8214
# Epoch 57/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0441 - accuracy: 0.8571
# Epoch 58/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0260 - accuracy: 0.8571
# Epoch 59/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0088 - accuracy: 0.8571
# Epoch 60/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9917 - accuracy: 0.8929
# Epoch 61/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9740 - accuracy: 0.8929
# Epoch 62/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9578 - accuracy: 0.8929
# Epoch 63/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9406 - accuracy: 0.8929
# Epoch 64/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9248 - accuracy: 0.8929
# Epoch 65/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9085 - accuracy: 0.8929
# Epoch 66/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8927 - accuracy: 0.8929
# Epoch 67/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8771 - accuracy: 0.8929
# Epoch 68/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8617 - accuracy: 0.8929
# Epoch 69/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8459 - accuracy: 0.8929
# Epoch 70/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8316 - accuracy: 0.8929
# Epoch 71/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8162 - accuracy: 0.8929
# Epoch 72/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8006 - accuracy: 0.8929
# Epoch 73/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7868 - accuracy: 0.8929
# Epoch 74/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7725 - accuracy: 0.8929
# Epoch 75/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7580 - accuracy: 0.8929
# Epoch 76/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7442 - accuracy: 0.8929
# Epoch 77/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7309 - accuracy: 0.8929
# Epoch 78/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7167 - accuracy: 0.8929
# Epoch 79/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7028 - accuracy: 0.8929
# Epoch 80/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6901 - accuracy: 0.8929
# Epoch 81/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6767 - accuracy: 0.8929
# Epoch 82/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6633 - accuracy: 0.8929
# Epoch 83/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6505 - accuracy: 0.8929
# Epoch 84/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6374 - accuracy: 0.8929
# Epoch 85/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6250 - accuracy: 0.8929
# Epoch 86/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6125 - accuracy: 0.8929
# Epoch 87/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5995 - accuracy: 0.8929
# Epoch 88/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5881 - accuracy: 0.8929
# Epoch 89/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5763 - accuracy: 0.8929
# Epoch 90/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5650 - accuracy: 0.8929
# Epoch 91/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5536 - accuracy: 0.8929
# Epoch 92/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5422 - accuracy: 0.9286
# Epoch 93/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5312 - accuracy: 0.9286
# Epoch 94/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5208 - accuracy: 0.9286
# Epoch 95/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5102 - accuracy: 0.9286
# Epoch 96/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4995 - accuracy: 0.9286
# Epoch 97/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4889 - accuracy: 0.9286
# Epoch 98/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4786 - accuracy: 0.9286
# Epoch 99/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4690 - accuracy: 0.9643
# Epoch 100/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4593 - accuracy: 0.9643

# %%
import pickle
pickle.dump({'words':words, 'classes':classes},open("training_data", 'wb'))
#the "rb" mode opens the file in binary format for reading, while the "wb" mode opens the file in binary format for writing.

# %%
from keras.models import load_model
model = load_model("model.pkl")

# %%
# restoring all the data structures
data = pickle.load(open("training_data", "rb"))
words = data['words']
classes = data['classes']

# %%
with open('/content/drive/MyDrive/Hands on Python/intents.json') as json_data:
  intents = json.load(json_data)

# %%
def clean_up_sentence(sentence):
  # tokenizing the pattern
  sentence_words = nltk.word_tokenize(sentence)
  # stemming the word
  sentence_words = [stemmer.stem(word.lower()) for word in sentence_words]
  return sentence_words

# returning the bag of words array : 0 or 1 for each word in the bag that exists in the sentence
def bow(sentence, words):
  # tokenizing the pattern
  sentence_words = clean_up_sentence(sentence)
  # generating bag of words
  bag = [0]*len(words)
  for s in sentence_words:
    for i,w in enumerate(words): #enumerates prints tuples of index and element pairs.
      if w == s:
        bag[i] = 1
  bag = np.array(bag)
  return(bag)

# %%
ERROR_THRESHOLD = 0.3
def classify(sentence):
  # generate probabilities from the model
  bag = bow(sentence, words)
  results = model.predict(np.array([bag]))
  # filter out predictions below the threshold
  results = [[i,r] for i,r in enumerate(results[0]) if r>ERROR_THRESHOLD]
  # sort by strength of probabilty
  results.sort(key = lambda x:x[1],reverse = True)
  return_list = []
  for r in results:
    return_list.append((classes[r[0]],r[1]))
  #return tuple of intent and probability
  return return_list

def response(sentence):
  results = classify(sentence)
  # if we have a classification then find matchin intent tag
  if results:
    # loop as long as there are matches to process
    while results:
      for i in intents['intents']:
        # find a tag matching the first result
        if i['tag'] == results[0][0]:
          # a random respomse from intent
          return print(random.choice(i['responses']))
      results.pop(0)

# %%
response("how are you")
# Out:
# 1/1 [==============================] - 0s 55ms/step
# I am good
